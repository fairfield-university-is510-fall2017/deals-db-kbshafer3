# %%
from sqlalchemy import create_engine
engine = create_engine("mysql+pymysql://root:mysql@localhost/deals")

# %%
SELECT *
FROM Companies
ORDER BY CompanyID;
# Out:
#   File "<ipython-input-2-71b785bdcbbc>", line 1
#     SELECT *
#             ^
# SyntaxError: invalid syntax

# %%
# initialize a %ssql database connection
# %Sql mysql+pymysql://root:mysql@localhost/deals
# Out:
# ERROR:root:Line magic function `%Sql` not found.

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
# initialize a %ssql database connection
# %sql mysql+pymysql://root:mysql@localhost/deals
# Out:
# 'Connected: root@deals'

# %% [markdown]
# # Select companies sorted by CompanyName

# %% [raw]
# %%sql
# # Select companies sorted by CompanyName
# SELECT *
# FROM Companies
# ORDER BY CompanyID;

# %% [markdown]
# Select Deal Parts with dollar values

# %%
# %%sql
# SELECT DealName, PartNumber, DollarValue
# FROM Deals,DealParts
# WHERE Deals.DealID = DealParts.DealID;
# Out:
# 158 rows affected.
# [('ADT Limited', 1, Decimal('5600.0000')),
#  ('Advanta Corp.', 1, Decimal('1300.0000')),
#  ('Alex. Brown Inc.', 1, Decimal('1700.0000')),
#  ('Allied Colloids Group PLC', 1, Decimal('1810.0000')),
#  ('American First Financial Insurance Group Inc.', 1, Decimal('2200.0000')),
#  ('American Medical Response, Inc.', 1, Decimal('1120.0000')),
#  ('American Radio Systems Corp.', 1, Decimal('2600.0000')),
#  ('American Standard Companies, Inc.', 1, Decimal('4000.0000')),
#  ('Amerisource Health Corp.', 1, Decimal('2322.0000')),
#  ('Amphenol Corp.', 1, Decimal('1500.0000')),
#  ('Apria Healthcare Group Inc.', 1, Decimal('1450.0000')),
#  ('AT&T Capital Corp.', 1, Decimal('1600.0000')),
#  ('Bankamerica Corp.', 1, Decimal('1600.0000')),
#  ('Barnett Banks, Inc.', 1, Decimal('15500.0000')),
#  ('BDM International', 1, Decimal('1000.0000')),
#  ('Beacon Properties Corp.', 1, Decimal('4000.0000')),
#  ('Bergen Brunswig Corp.', 1, Decimal('2500.0000')),
#  ('Berliner Kraft & Licht AG', 1, Decimal('1870.0000')),
#  ('Brooks Fiber Properties, Inc.', 1, Decimal('2900.0000')),
#  ('Browning-Ferris Industries Inc.', 1, Decimal('1450.0000')),
#  ('Calilber Systems Inc.', 1, Decimal('2237.0000')),
#  ('Cascade Communications Corp.', 1, Decimal('3700.0000')),
#  ('Celebrity Cruise Lines Inc', 1, Decimal('1300.0000')),
#  ('Celebrity Cruise Lines Inc', 2, Decimal('1325.0000')),
#  ('Central & South West Corp.', 1, Decimal('6600.0000')),
#  ('Central Fidelity Banks Inc.', 1, Decimal('2300.0000')),
#  ('Chancellor Broadcasting Comp.', 1, Decimal('1600.0000')),
#  ('Chauvco Resources LTD.', 1, Decimal('1197.0000')),
#  ('Cifra S.A.', 1, Decimal('1200.0000')),
#  ('Cigna Corporation', 1, Decimal('1400.0000')),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 1, Decimal('1617.0000')),
#  ('Coopers & Lybrand L.L.P.', 1, Decimal('12000.0000')),
#  ('Corestates Financial Corp.', 1, Decimal('18000.0000')),
#  ('Coulter Corp.', 1, Decimal('1050.0000')),
#  ('Cowles Media Company', 1, Decimal('1490.0000')),
#  ('Dauphin Deposit Corp.', 1, Decimal('1360.0000')),
#  ('Doubletree Corporation', 1, Decimal('2000.0000')),
#  ('DQE Inc.', 1, Decimal('4210.0000')),
#  ('Eller Media Corp.', 1, Decimal('1150.0000')),
#  ('Equitable of Iowa Companies', 1, Decimal('2600.0000')),
#  ('Ernst & Young LLP', 1, Decimal('13000.0000')),
#  ('Evans Withycombe Residential Inc.', 1, Decimal('1057.0000')),
#  ('Falcon Drilling Co.', 1, Decimal('2500.0000')),
#  ('First Commerce Corp.', 1, Decimal('3000.0000')),
#  ('First Financial Corp.', 1, Decimal('1050.0000')),
#  ('First of America Bank Corp.', 1, Decimal('6800.0000')),
#  ('First USA, Inc.', 1, Decimal('7000.0000')),
#  ('Fisher Scientific International Inc.', 1, Decimal('1060.0000')),
#  ('Fort Howard Corp.', 1, Decimal('3400.0000')),
#  ('General Motors Corp.', 1, Decimal('9500.0000')),
#  ('Great Western Financial Corp.', 1, Decimal('6590.0000')),
#  ('Greenfield Industries, Inc.', 1, Decimal('1000.0000')),
#  ('H&R Block Inc.', 1, Decimal('1200.0000')),
#  ('Healthsource, Inc.', 1, Decimal('1700.0000')),
#  ('Healthsouth Corp.', 1, Decimal('1250.0000')),
#  ('Hercules Inc. and Mallickrodt Inc', 1, Decimal('1100.0000')),
#  ('Heritage Media Corp.', 1, Decimal('1355.0000')),
#  ('Hermann Healthcare System', 1, Decimal('1000.0000')),
#  ('HFS Inc.', 1, Decimal('10900.0000')),
#  ('Homeside, Inc.', 1, Decimal('1230.0000')),
#  ('Horizon/CMS Healthcare Corp.', 1, Decimal('1650.0000')),
#  ('Imperial Chemical Industries PLC', 1, Decimal('3000.0000')),
#  ('International Family Entertainment Inc.', 1, Decimal('1900.0000')),
#  ('Interstate Hotel Company', 1, Decimal('1300.0000')),
#  ('Interstate Hotel Company', 2, Decimal('1340.0000')),
#  ('ITT Corp.', 1, Decimal('6500.0000')),
#  ('ITT Corp.', 1, Decimal('9300.0000')),
#  ('ITT Corp.', 2, Decimal('10200.0000')),
#  ('Johnson & Higgins', 1, Decimal('1800.0000')),
#  ('Keystone International Inc.', 1, Decimal('1200.0000')),
#  ('KU Energy Corporation', 1, Decimal('1500.0000')),
#  ('Laidlaw Inc.', 1, Decimal('1230.0000')),
#  ('Lin Television Corp.', 1, Decimal('1710.0000')),
#  ('Lin Television Corp.', 1, Decimal('1900.0000')),
#  ('Lin Television Corp.', 2, Decimal('2000.0000')),
#  ('Lincoln National Corporation', 1, Decimal('2820.0000')),
#  ('Living Centers of America Inc.', 1, Decimal('1000.0000')),
#  ('Lucas Varity PLC', 1, Decimal('1330.0000')),
#  ("Mac Frugal's Bargains & Close-Outs Inc.", 1, Decimal('1000.0000')),
#  ('MAPCO Inc.', 1, Decimal('3460.0000')),
#  ('MCI Communications Corporation', 1, Decimal('20880.0000')),
#  ('MCI Communications Corporation', 2, Decimal('28000.0000')),
#  ('MCI Communications Corporation', 3, Decimal('30000.0000')),
#  ('Medpartners, Inc.', 1, Decimal('8180.0000')),
#  ('Mercury Asset Management Group, P.L.C.', 1, Decimal('5300.0000')),
#  ('Minnesota Mining and Manufacturing Comp.', 1, Decimal('1000.0000')),
#  ('Monterey Resources Inc.', 1, Decimal('1100.0000')),
#  ('Montgomery Securities', 1, Decimal('1200.0000')),
#  ('Morgan Stanley Group Inc.', 1, Decimal('10500.0000')),
#  ('Nellcor Puritan Bennett Inc.', 1, Decimal('1900.0000')),
#  ('Network General Corp.', 1, Decimal('1300.0000')),
#  ('New York State Electric & Gas Corp.', 1, Decimal('1920.0000')),
#  ('Northrop Grumman Corp.', 1, Decimal('8260.0000')),
#  ('Octel Communications Corporation', 1, Decimal('1800.0000')),
#  ('Pacificorp', 1, Decimal('2223.0000')),
#  ('Parker & Parsley Petrolium Company', 1, Decimal('1800.0000')),
#  ('Pennzoil Comp.', 1, Decimal('6200.0000')),
#  ('Powernet Victoria', 1, Decimal('1880.0000')),
#  ('Quality Food Centers Inc.', 1, Decimal('1700.0000')),
#  ('Ralphs Grocery Company', 1, Decimal('3100.0000')),
#  ('Ralston Purina Co.', 1, Decimal('1500.0000')),
#  ('Read-Rite Corp.', 1, Decimal('1700.0000')),
#  ('Renaissance Hotel Group N.V.', 1, Decimal('1000.0000')),
#  ('Renal Treatment Centers Inc.', 1, Decimal('1100.0000')),
#  ('Retail Property Trust', 1, Decimal('1000.0000')),
#  ('Revco D.S., Inc.', 1, Decimal('3700.0000')),
#  ('Rohr Inc.', 1, Decimal('1216.0000')),
#  ('Rykoff Sexton Inc.', 1, Decimal('1389.0000')),
#  ('Safety-Kleen Corp.', 1, Decimal('1800.0000')),
#  ('Salomon Inc.', 1, Decimal('9000.0000')),
#  ('Santa Fe Pacific Pipeline Partners', 1, Decimal('1100.0000')),
#  ('Scudder, Stevens & Clark Inc.', 1, Decimal('1667.0000')),
#  ('Seagram Company', 1, Decimal('4100.0000')),
#  ('SFX Broadcasting Inc.', 1, Decimal('1200.0000')),
#  ('Showboat Inc.', 1, Decimal('1283.0000')),
#  ('Signet Banking Corp.', 1, Decimal('3250.0000')),
#  ('Sodexho Alliance S.A.', 1, Decimal('2000.0000')),
#  ('Sony Corporation of America', 1, Decimal('1000.0000')),
#  ('Starwood Lodging Corp.', 1, Decimal('2100.0000')),
#  ('Stone-Consolidated Corp.', 1, Decimal('1500.0000')),
#  ('T&N PLC', 1, Decimal('2300.0000')),
#  ('Tambrands Inc.', 1, Decimal('2000.0000')),
#  ('Tandem Computers Inc.', 1, Decimal('3000.0000')),
#  ('Target Therapeutics, Inc.', 1, Decimal('1100.0000')),
#  ('Tejas Gas Corp.', 1, Decimal('2350.0000')),
#  ('Telco Communications Group Inc.', 1, Decimal('1080.0000')),
#  ('Tencor Instruments Inc.', 1, Decimal('1300.0000')),
#  ('Texas Instruments Inc.', 1, Decimal('2950.0000')),
#  ('The Dow Chemical Company', 1, Decimal('1270.0000')),
#  ('The Dow Chemical Company', 1, Decimal('1300.0000')),
#  ('The Dow Chemical Company', 2, Decimal('1700.0000')),
#  ('The Energy Group PLC', 1, Decimal('9700.0000')),
#  ('The Louisiana Land and Exploration Company', 1, Decimal('3000.0000')),
#  ('The Multicare Companies, Inc.', 1, Decimal('1392.0000')),
#  ('The Quick & Reilly Group, Inc.', 1, Decimal('1600.0000')),
#  ('The Unilever Group', 1, Decimal('8000.0000')),
#  ('Transamerica Corp.', 1, Decimal('1100.0000')),
#  ('U.S. Bancorp', 1, Decimal('9000.0000')),
#  ('U.S. Robotics Corp.', 1, Decimal('7300.0000')),
#  ('U.S. West, Inc.', 1, Decimal('5000.0000')),
#  ('United Meridian Corp.', 1, Decimal('1200.0000')),
#  ('United Waste Systems, Inc.', 1, Decimal('1500.0000')),
#  ('Universal Outdoor Holdings Inc.', 1, Decimal('1750.0000')),
#  ('Uslife Corp.', 1, Decimal('1770.0000')),
#  ('Valero Energy Corp.', 1, Decimal('1500.0000')),
#  ('Value Health, Inc.', 1, Decimal('1300.0000')),
#  ('Verifone, Inc.', 1, Decimal('1180.0000')),
#  ('Viacom Inc.', 1, Decimal('1075.0000')),
#  ('Viacom Inc.', 1, Decimal('1700.0000')),
#  ('Vivra Inc.', 1, Decimal('1590.0000')),
#  ('W.R. Grace & Comp.', 1, Decimal('4900.0000')),
#  ('Western National Corp.', 1, Decimal('1200.0000')),
#  ('Westin Hotels & Resorts', 1, Decimal('1780.0000')),
#  ('Westinghouse Electric Corp.', 1, Decimal('2560.0000')),
#  ('Westinghouse Electric Corp.', 1, Decimal('1525.0000')),
#  ('Wyndham Hotel Corp.', 1, Decimal('1100.0000')),
#  ('Yorkshire Electricity', 1, Decimal('2800.0000')),
#  ('Zilkha Energy Co.', 1, Decimal('1040.0000'))]

# %% [markdown]
# # Select Deal Parts with dollar values using a join

# %%
# %%sql
# SELECT DealName, PartNumber, DollarValue
# FROM Deals JOIN DealParts on (Deals.DealID=DealParts.DealID);
# Out:
# 158 rows affected.
# [('ADT Limited', 1, Decimal('5600.0000')),
#  ('Advanta Corp.', 1, Decimal('1300.0000')),
#  ('Alex. Brown Inc.', 1, Decimal('1700.0000')),
#  ('Allied Colloids Group PLC', 1, Decimal('1810.0000')),
#  ('American First Financial Insurance Group Inc.', 1, Decimal('2200.0000')),
#  ('American Medical Response, Inc.', 1, Decimal('1120.0000')),
#  ('American Radio Systems Corp.', 1, Decimal('2600.0000')),
#  ('American Standard Companies, Inc.', 1, Decimal('4000.0000')),
#  ('Amerisource Health Corp.', 1, Decimal('2322.0000')),
#  ('Amphenol Corp.', 1, Decimal('1500.0000')),
#  ('Apria Healthcare Group Inc.', 1, Decimal('1450.0000')),
#  ('AT&T Capital Corp.', 1, Decimal('1600.0000')),
#  ('Bankamerica Corp.', 1, Decimal('1600.0000')),
#  ('Barnett Banks, Inc.', 1, Decimal('15500.0000')),
#  ('BDM International', 1, Decimal('1000.0000')),
#  ('Beacon Properties Corp.', 1, Decimal('4000.0000')),
#  ('Bergen Brunswig Corp.', 1, Decimal('2500.0000')),
#  ('Berliner Kraft & Licht AG', 1, Decimal('1870.0000')),
#  ('Brooks Fiber Properties, Inc.', 1, Decimal('2900.0000')),
#  ('Browning-Ferris Industries Inc.', 1, Decimal('1450.0000')),
#  ('Calilber Systems Inc.', 1, Decimal('2237.0000')),
#  ('Cascade Communications Corp.', 1, Decimal('3700.0000')),
#  ('Celebrity Cruise Lines Inc', 1, Decimal('1300.0000')),
#  ('Celebrity Cruise Lines Inc', 2, Decimal('1325.0000')),
#  ('Central & South West Corp.', 1, Decimal('6600.0000')),
#  ('Central Fidelity Banks Inc.', 1, Decimal('2300.0000')),
#  ('Chancellor Broadcasting Comp.', 1, Decimal('1600.0000')),
#  ('Chauvco Resources LTD.', 1, Decimal('1197.0000')),
#  ('Cifra S.A.', 1, Decimal('1200.0000')),
#  ('Cigna Corporation', 1, Decimal('1400.0000')),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 1, Decimal('1617.0000')),
#  ('Coopers & Lybrand L.L.P.', 1, Decimal('12000.0000')),
#  ('Corestates Financial Corp.', 1, Decimal('18000.0000')),
#  ('Coulter Corp.', 1, Decimal('1050.0000')),
#  ('Cowles Media Company', 1, Decimal('1490.0000')),
#  ('Dauphin Deposit Corp.', 1, Decimal('1360.0000')),
#  ('Doubletree Corporation', 1, Decimal('2000.0000')),
#  ('DQE Inc.', 1, Decimal('4210.0000')),
#  ('Eller Media Corp.', 1, Decimal('1150.0000')),
#  ('Equitable of Iowa Companies', 1, Decimal('2600.0000')),
#  ('Ernst & Young LLP', 1, Decimal('13000.0000')),
#  ('Evans Withycombe Residential Inc.', 1, Decimal('1057.0000')),
#  ('Falcon Drilling Co.', 1, Decimal('2500.0000')),
#  ('First Commerce Corp.', 1, Decimal('3000.0000')),
#  ('First Financial Corp.', 1, Decimal('1050.0000')),
#  ('First of America Bank Corp.', 1, Decimal('6800.0000')),
#  ('First USA, Inc.', 1, Decimal('7000.0000')),
#  ('Fisher Scientific International Inc.', 1, Decimal('1060.0000')),
#  ('Fort Howard Corp.', 1, Decimal('3400.0000')),
#  ('General Motors Corp.', 1, Decimal('9500.0000')),
#  ('Great Western Financial Corp.', 1, Decimal('6590.0000')),
#  ('Greenfield Industries, Inc.', 1, Decimal('1000.0000')),
#  ('H&R Block Inc.', 1, Decimal('1200.0000')),
#  ('Healthsource, Inc.', 1, Decimal('1700.0000')),
#  ('Healthsouth Corp.', 1, Decimal('1250.0000')),
#  ('Hercules Inc. and Mallickrodt Inc', 1, Decimal('1100.0000')),
#  ('Heritage Media Corp.', 1, Decimal('1355.0000')),
#  ('Hermann Healthcare System', 1, Decimal('1000.0000')),
#  ('HFS Inc.', 1, Decimal('10900.0000')),
#  ('Homeside, Inc.', 1, Decimal('1230.0000')),
#  ('Horizon/CMS Healthcare Corp.', 1, Decimal('1650.0000')),
#  ('Imperial Chemical Industries PLC', 1, Decimal('3000.0000')),
#  ('International Family Entertainment Inc.', 1, Decimal('1900.0000')),
#  ('Interstate Hotel Company', 1, Decimal('1300.0000')),
#  ('Interstate Hotel Company', 2, Decimal('1340.0000')),
#  ('ITT Corp.', 1, Decimal('6500.0000')),
#  ('ITT Corp.', 1, Decimal('9300.0000')),
#  ('ITT Corp.', 2, Decimal('10200.0000')),
#  ('Johnson & Higgins', 1, Decimal('1800.0000')),
#  ('Keystone International Inc.', 1, Decimal('1200.0000')),
#  ('KU Energy Corporation', 1, Decimal('1500.0000')),
#  ('Laidlaw Inc.', 1, Decimal('1230.0000')),
#  ('Lin Television Corp.', 1, Decimal('1710.0000')),
#  ('Lin Television Corp.', 1, Decimal('1900.0000')),
#  ('Lin Television Corp.', 2, Decimal('2000.0000')),
#  ('Lincoln National Corporation', 1, Decimal('2820.0000')),
#  ('Living Centers of America Inc.', 1, Decimal('1000.0000')),
#  ('Lucas Varity PLC', 1, Decimal('1330.0000')),
#  ("Mac Frugal's Bargains & Close-Outs Inc.", 1, Decimal('1000.0000')),
#  ('MAPCO Inc.', 1, Decimal('3460.0000')),
#  ('MCI Communications Corporation', 1, Decimal('20880.0000')),
#  ('MCI Communications Corporation', 2, Decimal('28000.0000')),
#  ('MCI Communications Corporation', 3, Decimal('30000.0000')),
#  ('Medpartners, Inc.', 1, Decimal('8180.0000')),
#  ('Mercury Asset Management Group, P.L.C.', 1, Decimal('5300.0000')),
#  ('Minnesota Mining and Manufacturing Comp.', 1, Decimal('1000.0000')),
#  ('Monterey Resources Inc.', 1, Decimal('1100.0000')),
#  ('Montgomery Securities', 1, Decimal('1200.0000')),
#  ('Morgan Stanley Group Inc.', 1, Decimal('10500.0000')),
#  ('Nellcor Puritan Bennett Inc.', 1, Decimal('1900.0000')),
#  ('Network General Corp.', 1, Decimal('1300.0000')),
#  ('New York State Electric & Gas Corp.', 1, Decimal('1920.0000')),
#  ('Northrop Grumman Corp.', 1, Decimal('8260.0000')),
#  ('Octel Communications Corporation', 1, Decimal('1800.0000')),
#  ('Pacificorp', 1, Decimal('2223.0000')),
#  ('Parker & Parsley Petrolium Company', 1, Decimal('1800.0000')),
#  ('Pennzoil Comp.', 1, Decimal('6200.0000')),
#  ('Powernet Victoria', 1, Decimal('1880.0000')),
#  ('Quality Food Centers Inc.', 1, Decimal('1700.0000')),
#  ('Ralphs Grocery Company', 1, Decimal('3100.0000')),
#  ('Ralston Purina Co.', 1, Decimal('1500.0000')),
#  ('Read-Rite Corp.', 1, Decimal('1700.0000')),
#  ('Renaissance Hotel Group N.V.', 1, Decimal('1000.0000')),
#  ('Renal Treatment Centers Inc.', 1, Decimal('1100.0000')),
#  ('Retail Property Trust', 1, Decimal('1000.0000')),
#  ('Revco D.S., Inc.', 1, Decimal('3700.0000')),
#  ('Rohr Inc.', 1, Decimal('1216.0000')),
#  ('Rykoff Sexton Inc.', 1, Decimal('1389.0000')),
#  ('Safety-Kleen Corp.', 1, Decimal('1800.0000')),
#  ('Salomon Inc.', 1, Decimal('9000.0000')),
#  ('Santa Fe Pacific Pipeline Partners', 1, Decimal('1100.0000')),
#  ('Scudder, Stevens & Clark Inc.', 1, Decimal('1667.0000')),
#  ('Seagram Company', 1, Decimal('4100.0000')),
#  ('SFX Broadcasting Inc.', 1, Decimal('1200.0000')),
#  ('Showboat Inc.', 1, Decimal('1283.0000')),
#  ('Signet Banking Corp.', 1, Decimal('3250.0000')),
#  ('Sodexho Alliance S.A.', 1, Decimal('2000.0000')),
#  ('Sony Corporation of America', 1, Decimal('1000.0000')),
#  ('Starwood Lodging Corp.', 1, Decimal('2100.0000')),
#  ('Stone-Consolidated Corp.', 1, Decimal('1500.0000')),
#  ('T&N PLC', 1, Decimal('2300.0000')),
#  ('Tambrands Inc.', 1, Decimal('2000.0000')),
#  ('Tandem Computers Inc.', 1, Decimal('3000.0000')),
#  ('Target Therapeutics, Inc.', 1, Decimal('1100.0000')),
#  ('Tejas Gas Corp.', 1, Decimal('2350.0000')),
#  ('Telco Communications Group Inc.', 1, Decimal('1080.0000')),
#  ('Tencor Instruments Inc.', 1, Decimal('1300.0000')),
#  ('Texas Instruments Inc.', 1, Decimal('2950.0000')),
#  ('The Dow Chemical Company', 1, Decimal('1270.0000')),
#  ('The Dow Chemical Company', 1, Decimal('1300.0000')),
#  ('The Dow Chemical Company', 2, Decimal('1700.0000')),
#  ('The Energy Group PLC', 1, Decimal('9700.0000')),
#  ('The Louisiana Land and Exploration Company', 1, Decimal('3000.0000')),
#  ('The Multicare Companies, Inc.', 1, Decimal('1392.0000')),
#  ('The Quick & Reilly Group, Inc.', 1, Decimal('1600.0000')),
#  ('The Unilever Group', 1, Decimal('8000.0000')),
#  ('Transamerica Corp.', 1, Decimal('1100.0000')),
#  ('U.S. Bancorp', 1, Decimal('9000.0000')),
#  ('U.S. Robotics Corp.', 1, Decimal('7300.0000')),
#  ('U.S. West, Inc.', 1, Decimal('5000.0000')),
#  ('United Meridian Corp.', 1, Decimal('1200.0000')),
#  ('United Waste Systems, Inc.', 1, Decimal('1500.0000')),
#  ('Universal Outdoor Holdings Inc.', 1, Decimal('1750.0000')),
#  ('Uslife Corp.', 1, Decimal('1770.0000')),
#  ('Valero Energy Corp.', 1, Decimal('1500.0000')),
#  ('Value Health, Inc.', 1, Decimal('1300.0000')),
#  ('Verifone, Inc.', 1, Decimal('1180.0000')),
#  ('Viacom Inc.', 1, Decimal('1075.0000')),
#  ('Viacom Inc.', 1, Decimal('1700.0000')),
#  ('Vivra Inc.', 1, Decimal('1590.0000')),
#  ('W.R. Grace & Comp.', 1, Decimal('4900.0000')),
#  ('Western National Corp.', 1, Decimal('1200.0000')),
#  ('Westin Hotels & Resorts', 1, Decimal('1780.0000')),
#  ('Westinghouse Electric Corp.', 1, Decimal('2560.0000')),
#  ('Westinghouse Electric Corp.', 1, Decimal('1525.0000')),
#  ('Wyndham Hotel Corp.', 1, Decimal('1100.0000')),
#  ('Yorkshire Electricity', 1, Decimal('2800.0000')),
#  ('Zilkha Energy Co.', 1, Decimal('1040.0000'))]

# %% [markdown]
# # Show each company involved in each deal.

# %%
# %%sql
# SELECT DealName,RoleCode,CompanyName
# FROM Companies
# JOIN Players ON (Companies.CompanyID = Players.CompanyID)
# JOIN Deals ON (Players.DealID = Deals.DealID)
# ORDER BY DealName;
# Out:
# 332 rows affected.
# [('ADT Limited', 'B1', 'Western Resources, Inc.'),
#  ('ADT Limited', 'B2', 'Tyco International Ltd.'),
#  ('ADT Limited', 'T', 'ADT Limited'),
#  ('Advanta Corp.', 'A', 'Fleet Financial Group, Inc.'),
#  ('Advanta Corp.', 'T', 'Advanta Corp. Credit card unit'),
#  ('Alex. Brown Inc.', 'A', 'Bankers Trust New York Corporation'),
#  ('Alex. Brown Inc.', 'T', 'Alex. Brown Inc.'),
#  ('Allied Colloids Group PLC', 'T', 'Allied Colloids Group'),
#  ('Allied Colloids Group PLC', 'B1', 'Hercules Inc.'),
#  ('American First Financial Insurance Group Inc.', 'T', 'American Bankers Insurance Group Inc.'),
#  ('American First Financial Insurance Group Inc.', 'A', 'American International Group Inc.'),
#  ('American Medical Response, Inc.', 'A', 'Laidlaw Inc.'),
#  ('American Medical Response, Inc.', 'T', 'American Medical Response, Inc.'),
#  ('American Radio Systems Corp.', 'A', 'Westinghouse Electric Corp.'),
#  ('American Radio Systems Corp.', 'T', 'American Radio Systems Corp.'),
#  ('American Standard Companies, Inc.', 'B', 'Tyco International Ltd.'),
#  ('American Standard Companies, Inc.', 'T', 'American Standard Companies, Inc.'),
#  ('Amerisource Health Corp.', 'A', 'McKesson Corp.'),
#  ('Amerisource Health Corp.', 'T', 'Amerisource Health Corp.'),
#  ('Amphenol Corp.', 'A', 'Kohlberg Kravis Roberts & Co.'),
#  ('Amphenol Corp.', 'T', 'Amphenol Corp.'),
#  ('Apria Healthcare Group Inc.', 'A', 'Investor Group led by Transworld Healthcare Inc.'),
#  ('Apria Healthcare Group Inc.', 'T', 'Apria Healthcare Group Inc.'),
#  ('AT&T Capital Corp.', 'T', 'AT&T Capital Corp.'),
#  ('AT&T Capital Corp.', 'A', 'Newcourt Credit Group Inc.'),
#  ('Bankamerica Corp.', 'T', 'Security Pacific Financial Services'),
#  ('Barnett Banks, Inc.', 'A', 'NationsBank Corporation'),
#  ('Barnett Banks, Inc.', 'T', 'Barnett Banks, Inc.'),
#  ('BDM International', 'T', 'BDM International Inc.'),
#  ('BDM International', 'A', 'TRW Inc.'),
#  ('Beacon Properties Corp.', 'A', 'Equity Office Properties Trust'),
#  ('Beacon Properties Corp.', 'T', 'Beacon Properties Corp.'),
#  ('Bergen Brunswig Corp.', 'A', 'Cardinal Health, Inc.'),
#  ('Bergen Brunswig Corp.', 'T', 'Bergen Brunswig Corp.'),
#  ('Berliner Kraft & Licht AG', 'A', 'Inv. Group led by Southern Comp. and Viag AG'),
#  ('Brooks Fiber Properties, Inc.', 'A', 'WorldCom, Inc.'),
#  ('Brooks Fiber Properties, Inc.', 'T', 'Brooks Fiber Properties, Inc.'),
#  ('Browning-Ferris Industries Inc.', 'A', 'SITA SA'),
#  ('Browning-Ferris Industries Inc.', 'T', 'Browning-Ferris Ind. Foreign Waste Management unit'),
#  ('Calilber Systems Inc.', 'A', 'Federal Express Corporation'),
#  ('Calilber Systems Inc.', 'T', 'Calilber Systems Inc.'),
#  ('Cascade Communications Corp.', 'A', 'Ascend Communications, Inc.'),
#  ('Cascade Communications Corp.', 'T', 'Cascade Communications Corp.'),
#  ('Celebrity Cruise Lines Inc', 'A', 'Royal Caribbean Cruises Ltd.'),
#  ('Celebrity Cruise Lines Inc', 'B', 'Carnival Corporation'),
#  ('Celebrity Cruise Lines Inc', 'S', 'Overseas Shipholding Group, Inc.'),
#  ('Celebrity Cruise Lines Inc', 'T', 'Celebrity Cruise Lines Inc'),
#  ('Central & South West Corp.', 'T', 'Central & South West Corp.'),
#  ('Central & South West Corp.', 'A', 'American Electric Power Co.'),
#  ('Central Fidelity Banks Inc.', 'A', 'Wachovia Corporation'),
#  ('Central Fidelity Banks Inc.', 'T', 'Central Fidelity Banks Inc.'),
#  ('Chancellor Broadcasting Comp.', 'A', 'Evergreen Media Corporation'),
#  ('Chancellor Broadcasting Comp.', 'T', 'Chancellor Broadcasting Comp.'),
#  ('Chauvco Resources LTD.', 'A', 'Pioneer Natural Resources Co.'),
#  ('Chauvco Resources LTD.', 'T', 'Chauvco Resources Ltd.'),
#  ('Cifra S.A.', 'A', 'Wal-Mart Stores, Inc.'),
#  ('Cifra S.A.', 'T', 'Cifra S.A.'),
#  ('Cigna Corporation', 'A', 'Lincoln National Corporation'),
#  ('Cigna Corporation', 'S', 'Connecticut General Life Insurance Co.'),
#  ('Cigna Corporation', 'T', 'Cigna Corp. Life-Insurance and annuity untis'),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 'A', 'Coca-Cola Enterprises Inc.'),
#  ('Coca Cola Bottling Co. of New York and Coca-Cola B', 'T', 'Coca Cola Bottling Co. of New York and Coca-Cola B'),
#  ('Coopers & Lybrand L.L.P.', 'M', 'Price Waterhouse'),
#  ('Coopers & Lybrand L.L.P.', 'M', 'Coopers & Lybrand L.L.P.'),
#  ('Corestates Financial Corp.', 'A', 'First Union Corporation'),
#  ('Corestates Financial Corp.', 'B', 'Mellon Corp.'),
#  ('Corestates Financial Corp.', 'T', 'Corestates Financial Corp.'),
#  ('Coulter Corp.', 'T', 'Coulter Corp.'),
#  ('Coulter Corp.', 'A', 'Beckman Instruments, Inc.'),
#  ('Cowles Media Company', 'A', 'McClatchy Newspapers, Inc.'),
#  ('Cowles Media Company', 'T', 'Cowles Media Company'),
#  ('Dauphin Deposit Corp.', 'A', 'Allied Irish Banks P.L.C.'),
#  ('Dauphin Deposit Corp.', 'T', 'Dauphin Deposit Corp.'),
#  ('Doubletree Corporation', 'A', 'Promus Hotel Corp.'),
#  ('Doubletree Corporation', 'T', 'Doubletree Corporation'),
#  ('DQE Inc.', 'A', 'Allegheny Power System Inc.'),
#  ('DQE Inc.', 'T', 'DQE Inc.'),
#  ('Eller Media Corp.', 'A', 'Clear Channel Communications, Inc.'),
#  ('Eller Media Corp.', 'S', 'Hellman & Friedman'),
#  ('Eller Media Corp.', 'T', 'Eller Media Corp.'),
#  ('Equitable of Iowa Companies', 'A', 'ING Group NV'),
#  ('Equitable of Iowa Companies', 'T', 'Equitable of Iowa Companies'),
#  ('Ernst & Young LLP', 'M', 'KPMG Peat Marwick LLP'),
#  ('Ernst & Young LLP', 'M', 'Ernst & Young LLP'),
#  ('Evans Withycombe Residential Inc.', 'A', 'Equity Residential Properties Trust'),
#  ('Evans Withycombe Residential Inc.', 'T', 'Evans Withycombe Residential Inc.'),
#  ('Falcon Drilling Co.', 'A', 'Reading & Bates Corporation'),
#  ('Falcon Drilling Co.', 'T', 'Falcon Drilling Co.'),
#  ('First Commerce Corp.', 'A', 'Banc One Corporation'),
#  ('First Commerce Corp.', 'T', 'First Commerce Corp.'),
#  ('First Financial Corp.', 'A', 'Associated Banc-Corp'),
#  ('First Financial Corp.', 'T', 'First Financial Corp.'),
#  ('First of America Bank Corp.', 'T', 'First of America Bank Corp.'),
#  ('First of America Bank Corp.', 'A', 'National City Corp.'),
#  ('First USA, Inc.', 'A', 'Banc One Corporation'),
#  ('First USA, Inc.', 'T', 'First USA, Inc.'),
#  ('Fisher Scientific International Inc.', 'A', 'Inv. Group led by Thomas H. Lee Company'),
#  ('Fisher Scientific International Inc.', 'T', 'Fisher Scientific International Inc.'),
#  ('Fort Howard Corp.', 'A', 'James River Corp.'),
#  ('Fort Howard Corp.', 'T', 'Fort Howard Corp.'),
#  ('General Motors Corp.', 'A', 'Raytheon Company'),
#  ('General Motors Corp.', 'B', 'Northrop Grumman Corp.'),
#  ('General Motors Corp.', 'T', 'Hughes Electronics Corp.'),
#  ('Great Western Financial Corp.', 'B1', 'H.F. Ahmanson & Co.'),
#  ('Great Western Financial Corp.', 'B2', 'Washington Mutual Inc.'),
#  ('Great Western Financial Corp.', 'T', 'Great Western Financial Corp.'),
#  ('Greenfield Industries, Inc.', 'A', 'Kennametal Inc.'),
#  ('Greenfield Industries, Inc.', 'T', 'Greenfield Industries, Inc.'),
#  ('H&R Block Inc.', 'A', 'WorldCom, Inc.'),
#  ('H&R Block Inc.', 'T', 'CompuServe Corp.'),
#  ('Healthsource, Inc.', 'A', 'CIGNA Corporation'),
#  ('Healthsource, Inc.', 'T', 'Healthsource, Inc.'),
#  ('Healthsouth Corp.', 'A', 'Integrated Health Services Inc.'),
#  ('Healthsouth Corp.', 'T', 'Healthsouth Corp. Long term facilities'),
#  ('Hercules Inc. and Mallickrodt Inc', 'A', 'Roche Holding AG'),
#  ('Hercules Inc. and Mallickrodt Inc', 'T', 'Tastemaker'),
#  ('Heritage Media Corp.', 'A', 'The News Corporation Limited'),
#  ('Heritage Media Corp.', 'T', 'Heritage Media Corp.'),
#  ('Hermann Healthcare System', 'T', 'Hermann Healthcare System'),
#  ('Hermann Healthcare System', 'M', 'Memorial Healthcare System'),
#  ('HFS Inc.', 'A', 'CUC International Inc.'),
#  ('HFS Inc.', 'T', 'HFS Inc.'),
#  ('Homeside, Inc.', 'A', 'National Bank Australia Limited'),
#  ('Homeside, Inc.', 'S', 'Barnett Banks, Inc.'),
#  ('Homeside, Inc.', 'T', 'Homeside, Inc.'),
#  ('Horizon/CMS Healthcare Corp.', 'A', 'HealthSouth Corp.'),
#  ('Horizon/CMS Healthcare Corp.', 'T', 'Horizon/CMS Healthcare Corp.'),
#  ('Imperial Chemical Industries PLC', 'A', 'DuPont Co.'),
#  ('Imperial Chemical Industries PLC', 'T', 'Imperial Chemical, Industrial chemical businesses'),
#  ('International Family Entertainment Inc.', 'A', 'Fox Kids Worldwide Inc.'),
#  ('International Family Entertainment Inc.', 'S', 'Pat Robertson'),
#  ('International Family Entertainment Inc.', 'T', 'International Family Entertainment Inc.'),
#  ('International Family Entertainment Inc.', 'S', 'Liberty Media Corporation'),
#  ('International Family Entertainment Inc.', 'B', 'The Walt Disney Company'),
#  ('Interstate Hotel Company', 'T', 'Interstate Hotels Company'),
#  ('Interstate Hotel Company', 'B1', 'The Meditrust Corporation'),
#  ('Interstate Hotel Company', 'B2', 'Patriot American Hospitality Inc.'),
#  ('ITT Corp.', 'B1', 'Hilton Hotels Corp.'),
#  ('ITT Corp.', 'B2', 'Starwood Lodging Corp.'),
#  ('ITT Corp.', 'T', 'ITT Corp.'),
#  ('Johnson & Higgins', 'A', 'Marsh & McLennan Companies, Inc.'),
#  ('Johnson & Higgins', 'T', 'Johnson & Higgins'),
#  ('Keystone International Inc.', 'A', 'Tyco International Ltd.'),
#  ('Keystone International Inc.', 'S', 'Norwest Bank Texas, Trustee'),
#  ('Keystone International Inc.', 'T', 'Keystone International Inc.'),
#  ('KU Energy Corporation', 'A', 'LG&E Energy Corporation'),
#  ('KU Energy Corporation', 'T', 'KU Energy Corporation'),
#  ('Laidlaw Inc.', 'A', 'Rollins Environmental Services, Inc.'),
#  ('Laidlaw Inc.', 'T', 'Laidlaw Environmental Services, Inc. & Laidlaw Env'),
#  ('Lin Television Corp.', 'A', 'Hicks, Muse, Tate & Furst Inc. and NBC'),
#  ('Lin Television Corp.', 'B2', 'Raycom Media, Inc.'),
#  ('Lin Television Corp.', 'T', 'Lin Television Corp.'),
#  ('Lincoln National Corporation', 'A', 'Safeco Corporation'),
#  ('Lincoln National Corporation', 'T', 'American States Financial Corp.'),
#  ('Living Centers of America Inc.', 'M', 'Apollo Management L.P.'),
#  ('Living Centers of America Inc.', 'M', 'GranCare Inc.'),
#  ('Living Centers of America Inc.', 'M', 'Living Centers of America Inc.'),
#  ('Lucas Varity PLC', 'T', 'Perkins Engine unit'),
#  ('Lucas Varity PLC', 'A', 'Caterpillar Inc.'),
#  ("Mac Frugal's Bargains & Close-Outs Inc.", 'A', 'Consolidated Stores Corp.'),
#  ("Mac Frugal's Bargains & Close-Outs Inc.", 'T', "Mac Frugal's Bargains & Close-Outs Inc."),
#  ('MAPCO Inc.', 'T', 'Mapco Inc.'),
#  ('MAPCO Inc.', 'A', 'Williams Cos.'),
#  ('MCI Communications Corporation', 'B1', 'British Telecommunications PLC'),
#  ('MCI Communications Corporation', 'B2', 'WorldCom, Inc.'),
#  ('MCI Communications Corporation', 'T', 'MCI Communications Corporation'),
#  ('MCI Communications Corporation', 'B3', 'GTE Corp.'),
#  ('Medpartners, Inc.', 'A', 'PhyCor Inc.'),
#  ('Medpartners, Inc.', 'T', 'MedPartners, Inc.'),
#  ('Mercury Asset Management Group, P.L.C.', 'T', 'Mercury Asset Management Group, P.L.C.'),
#  ('Mercury Asset Management Group, P.L.C.', 'A', 'Merrill Lynch & Co.'),
#  ('Minnesota Mining and Manufacturing Comp.', 'A', 'Outdoor Systems Inc.'),
#  ('Minnesota Mining and Manufacturing Comp.', 'T', 'National Advertising Company'),
#  ('Monterey Resources Inc.', 'A', 'Texaco Inc.'),
#  ('Monterey Resources Inc.', 'T', 'Monterey Resources Inc.'),
#  ('Montgomery Securities', 'A', 'NationsBank Corporation'),
#  ('Montgomery Securities', 'T', 'Montgomery Securities'),
#  ('Morgan Stanley Group Inc.', 'A', 'Dean Witter Discover & Co.'),
#  ('Morgan Stanley Group Inc.', 'T', 'Morgan Stanley Group Inc.'),
#  ('Nellcor Puritan Bennett Inc.', 'A', 'Mallinckrodt Inc.'),
#  ('Nellcor Puritan Bennett Inc.', 'T', 'Nellcor Puritan Bennett Inc.'),
#  ('Network General Corp.', 'A', 'McAfee Associates Inc.'),
#  ('Network General Corp.', 'T', 'Network General Corp.'),
#  ('New York State Electric & Gas Corp.', 'A', 'CalEnergy Co.'),
#  ('New York State Electric & Gas Corp.', 'T', 'New York State Electric & Gas Corp.'),
#  ('Northrop Grumman Corp.', 'A', 'Lockheed Martin Corp.'),
#  ('Northrop Grumman Corp.', 'T', 'Northrop Grumman Corp.'),
#  ('Octel Communications Corporation', 'A', 'Lucent Technologies Inc.'),
#  ('Octel Communications Corporation', 'T', 'Octel Communications Corporation'),
#  ('Pacificorp', 'A', 'Century Telephone Enterprises Inc.'),
#  ('Pacificorp', 'T', 'Pacific Telecom Inc.'),
#  ('Parker & Parsley Petrolium Company', 'A', 'MESA, Inc.'),
#  ('Parker & Parsley Petrolium Company', 'T', 'Parker & Parsley Petrolium Company'),
#  ('Pennzoil Comp.', 'A', 'Union Pacific Resources Group Inc.'),
#  ('Pennzoil Comp.', 'T', 'Pennzoil Comp.'),
#  ('Powernet Victoria', 'A', 'GPU, Inc.'),
#  ('Powernet Victoria', 'T', 'PowerNet Victoria'),
#  ('Quality Food Centers Inc.', 'A', 'Fred Meyer Inc.'),
#  ('Quality Food Centers Inc.', 'S', 'Zell/Chillmark Fund'),
#  ('Quality Food Centers Inc.', 'T', 'Quality Food Centers Inc.'),
#  ('Ralphs Grocery Company', 'A', 'Fred Meyer Inc.'),
#  ('Ralphs Grocery Company', 'T', 'Ralphs Grocery Company'),
#  ('Ralphs Grocery Company', 'S', 'Apollo Advisors'),
#  ('Ralston Purina Co.', 'A', 'DuPont Co.'),
#  ('Ralston Purina Co.', 'T', 'Protein Technologies International'),
#  ('Read-Rite Corp.', 'A', 'Applied Magnetics Corp.'),
#  ('Read-Rite Corp.', 'T', 'Read-Rite Corp.'),
#  ('Renaissance Hotel Group N.V.', 'B1', 'Doubletree Corporation'),
#  ('Renaissance Hotel Group N.V.', 'B2', 'Marriott International, Inc.'),
#  ('Renaissance Hotel Group N.V.', 'D', 'Apollo Advisors'),
#  ('Renaissance Hotel Group N.V.', 'T', 'Renaissance Hotel Group N.V.'),
#  ('Renal Treatment Centers Inc.', 'T', 'Renal Treatment Centers Inc.'),
#  ('Renal Treatment Centers Inc.', 'A', 'Total Renal Care Holdings Inc.'),
#  ('Retail Property Trust', 'T', 'Retail Property Trust'),
#  ('Retail Property Trust', 'B1', 'New England Development'),
#  ('Retail Property Trust', 'B1', 'Richard E. Jacobs Group'),
#  ('Retail Property Trust', 'A', 'Simon DeBartolo Group Inc.'),
#  ('Retail Property Trust', 'D', "O'Connor Group (Managers of Property Trust)"),
#  ('Revco D.S., Inc.', 'A', 'CVS Corporation'),
#  ('Revco D.S., Inc.', 'T', 'Revco D.S., Inc.'),
#  ('Rohr Inc.', 'A', 'B.F. Goodrich Co.'),
#  ('Rohr Inc.', 'T', 'Rohr Inc.'),
#  ('Rykoff Sexton Inc.', 'A', 'JP Foodservice Inc.'),
#  ('Rykoff Sexton Inc.', 'S', 'Merrill Lynch Capital Partners'),
#  ('Rykoff Sexton Inc.', 'T', 'Rykoff Sexton Inc.'),
#  ('Safety-Kleen Corp.', 'A', 'Laidlaw Environmental Services, Inc.'),
#  ('Safety-Kleen Corp.', 'T', 'Safety-Kleen Corp.'),
#  ('Salomon Inc.', 'A', 'Travelers Group'),
#  ('Salomon Inc.', 'T', 'Salomon Inc.'),
#  ('Santa Fe Pacific Pipeline Partners', 'A', 'Kinder Morgan Energy Partners'),
#  ('Santa Fe Pacific Pipeline Partners', 'T', 'Santa Fe Pacific Pipeline Partners'),
#  ('Scudder, Stevens & Clark Inc.', 'A', 'Zurich Group'),
#  ('Scudder, Stevens & Clark Inc.', 'T', 'Scudder, Stevens & Clark Inc.'),
#  ('Seagram Company', 'A', 'HSN Inc.'),
#  ('Seagram Company', 'S', 'Tele-Communications, Inc.'),
#  ('Seagram Company', 'T', 'Universal Studios, Inc.'),
#  ('SFX Broadcasting Inc.', 'A', 'Hicks, Muse, Tate & Furst Inc.'),
#  ('SFX Broadcasting Inc.', 'D', 'Apollo Advisors'),
#  ('SFX Broadcasting Inc.', 'T', 'SFX Broadcasting Inc.'),
#  ('Showboat Inc.', 'T', 'Showboat Inc.'),
#  ('Showboat Inc.', 'A', "Harrah's Entertainment"),
#  ('Signet Banking Corp.', 'A', 'First Union Corporation'),
#  ('Signet Banking Corp.', 'T', 'Signet Banking Corp.'),
#  ('Sodexho Alliance S.A.', 'T', 'Sodexho Alliance S.A.'),
#  ('Sodexho Alliance S.A.', 'M', 'Marriott International, Inc.'),
#  ('Sony Corporation of America', 'M', 'Cineplex Odeon Corp.'),
#  ('Sony Corporation of America', 'S', 'Universal Studios, Inc.'),
#  ('Sony Corporation of America', 'T', 'Loews Theatre Exhibition Group'),
#  ('Sony Corporation of America', 'S', 'Charles Rosner Bronfman Family Trust'),
#  ('Starwood Lodging Corp.', 'T', 'ITT World Directories'),
#  ('Starwood Lodging Corp.', 'A', 'VNU NV'),
#  ('Stone-Consolidated Corp.', 'A', 'Abitibi-Price Inc.'),
#  ('Stone-Consolidated Corp.', 'T', 'Stone-Consolidated Corp.'),
#  ('T&N PLC', 'A', 'Federal-Mogul Corp.'),
#  ('T&N PLC', 'T', 'T&N PLC'),
#  ('Tambrands Inc.', 'A', 'Procter & Gamble Co.'),
#  ('Tambrands Inc.', 'T', 'Tambrands Inc.'),
#  ('Tandem Computers Inc.', 'A', 'Compaq Computer Corp.'),
#  ('Tandem Computers Inc.', 'T', 'Tandem Computers Inc.'),
#  ('Target Therapeutics, Inc.', 'A', 'Boston Scientific Corporation'),
#  ('Target Therapeutics, Inc.', 'T', 'Target Therapeutics, Inc.'),
#  ('Tejas Gas Corp.', 'A', 'Shell Oil Company'),
#  ('Tejas Gas Corp.', 'D', 'Apollo Advisors'),
#  ('Tejas Gas Corp.', 'T', 'Tejas Gas Corp.'),
#  ('Telco Communications Group Inc.', 'A', 'Excel Communications, Inc.'),
#  ('Telco Communications Group Inc.', 'D', 'Apollo Advisors'),
#  ('Telco Communications Group Inc.', 'T', 'Telco Communications Group Inc.'),
#  ('Tencor Instruments Inc.', 'A', 'KLA Instruments Corporation'),
#  ('Tencor Instruments Inc.', 'T', 'Tencor Instruments Inc.'),
#  ('Texas Instruments Inc.', 'A', 'Raytheon Company'),
#  ('Texas Instruments Inc.', 'T', "Texas instruments' Defense Systems & Electronics G"),
#  ('The Dow Chemical Company', 'A', 'NGC Corp.'),
#  ('The Dow Chemical Company', 'B', 'Calpine Corporation'),
#  ('The Dow Chemical Company', 'T', 'Destec Energy, Inc.'),
#  ('The Dow Chemical Company', 'A', 'S.C. Johnson & Son Inc.'),
#  ('The Dow Chemical Company', 'T', 'DowBrands Inc.'),
#  ('The Energy Group PLC', 'A', 'PacifiCorp'),
#  ('The Energy Group PLC', 'T', 'Energy Group PLC, The'),
#  ('The Louisiana Land and Exploration Company', 'A', 'Burlington Resources Inc.'),
#  ('The Louisiana Land and Exploration Company', 'T', 'Louisiana Land & Exploration'),
#  ('The Multicare Companies, Inc.', 'A', 'Genesis ElderCare Corp., Cypress Group & TX Pacifi'),
#  ('The Multicare Companies, Inc.', 'T', 'Multicare Companies, Inc., The'),
#  ('The Quick & Reilly Group, Inc.', 'A', 'Fleet Financial Group, Inc.'),
#  ('The Quick & Reilly Group, Inc.', 'T', 'Quick & Reilly Group, Inc., The'),
#  ('The Unilever Group', 'A', 'Imperial Chemical Industries PLC'),
#  ('The Unilever Group', 'T', 'The Unilever Group, Specialty Chemicals Unit'),
#  ('Transamerica Corp.', 'A', 'Household International Inc.'),
#  ('Transamerica Corp.', 'T', 'Transamerica Financial'),
#  ('U.S. Bancorp', 'M', 'First Bank System, Inc.'),
#  ('U.S. Bancorp', 'T', 'U.S. Bancorp'),
#  ('U.S. Robotics Corp.', 'A', '3Com Corporation'),
#  ('U.S. Robotics Corp.', 'T', 'U.S. Robotics Corp.'),
#  ('U.S. West, Inc.', 'A', 'AirTouch Communications, Inc.'),
#  ('U.S. West, Inc.', 'T', 'U.S. West Media Group'),
#  ('United Meridian Corp.', 'M', 'United Meridian Corp.'),
#  ('United Meridian Corp.', 'M', 'Ocean Energy Inc.'),
#  ('United Waste Systems, Inc.', 'A', 'USA Waste Services Inc.'),
#  ('United Waste Systems, Inc.', 'T', 'United Waste Systems, Inc.'),
#  ('Universal Outdoor Holdings Inc.', 'A', 'Clear Channel Communications, Inc.'),
#  ('Universal Outdoor Holdings Inc.', 'T', 'Universal Outdoor Holdings Inc.'),
#  ('Uslife Corp.', 'A', 'American General Corp.'),
#  ('Uslife Corp.', 'T', 'USLIFE Corp.'),
#  ('Valero Energy Corp.', 'A', 'PG&E Corporation'),
#  ('Valero Energy Corp.', 'T', 'Valero Energy Corp.'),
#  ('Value Health, Inc.', 'A', 'Columbia-HCA Healthcare Corporation'),
#  ('Value Health, Inc.', 'T', 'Value Health, Inc.'),
#  ('Verifone, Inc.', 'A', 'Hewlett-Packard Company'),
#  ('Verifone, Inc.', 'T', 'Verifone, Inc.'),
#  ('Viacom Inc.', 'A', 'Evergreen Media Corporation'),
#  ('Viacom Inc.', 'A', 'Vencor, Inc.'),
#  ('Viacom Inc.', 'T', 'Viacom Radio Group'),
#  ('Viacom Inc.', 'A', 'Seagram Co.'),
#  ('Viacom Inc.', 'T', 'USA Networks'),
#  ('Vivra Inc.', 'A', 'Incentive AB'),
#  ('Vivra Inc.', 'T', 'Vivra Inc.'),
#  ('W.R. Grace & Comp.', 'A', 'Sealed Air Corporation'),
#  ('W.R. Grace & Comp.', 'T', 'Cryovac'),
#  ('Western National Corp.', 'A', 'American General Corp.'),
#  ('Western National Corp.', 'T', 'Western National Corp.'),
#  ('Westin Hotels & Resorts', 'A', 'Starwood Lodging Trust'),
#  ('Westin Hotels & Resorts', 'T', 'Westin Hotels & Resorts'),
#  ('Westinghouse Electric Corp.', 'A', 'Ingersoll-Rand Company'),
#  ('Westinghouse Electric Corp.', 'T', 'Thermo King'),
#  ('Westinghouse Electric Corp.', 'A', 'Siemens A.G.'),
#  ('Westinghouse Electric Corp.', 'T', 'Westinghouse Power Generation'),
#  ('Wyndham Hotel Corp.', 'A', 'Patriot American Hospitality Inc.'),
#  ('Wyndham Hotel Corp.', 'S', 'Hampstead Group & GM Pension Trust'),
#  ('Wyndham Hotel Corp.', 'T', 'Wyndham Hotel Corp.'),
#  ('Yorkshire Electricity', 'A', 'American Electric Power Co. Inc. and Public Service'),
#  ('Yorkshire Electricity', 'T', 'Yorkshire Electricity Group plc'),
#  ('Zilkha Energy Co.', 'T', 'Zilkha Energy Co.'),
#  ('Zilkha Energy Co.', 'A', 'Sonat Inc.')]
